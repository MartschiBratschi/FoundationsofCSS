# %% [markdown]
# # The Importance of Schlager with Spotify API

# %% [markdown]
# ## 1. Import Spotify API

# %%
import requests

# Spotify API credentials
client_id = "4a5d601ff9e649a7912a92fd1754e733"
client_secret = "963527c72c4643b99a03679e61ddbdec"

# Get access token
auth_response = requests.post(
    "https://accounts.spotify.com/api/token",
    {
        "grant_type": "client_credentials",
        "client_id": client_id,
        "client_secret": client_secret,
    },
)
auth_response_data = auth_response.json()
access_token = auth_response_data["access_token"]

# Set up headers
headers = {"Authorization": f"Bearer {access_token}"}

# %% [markdown]
# ## 2. Getting Schlager tracks for timespan between 2008 & 2025

# %%
# Function to get Schlager tracks for a given year
def get_schlager_tracks_by_year(year):
    response = requests.get(
        "https://api.spotify.com/v1/search",
        headers=headers,
        params={"q": f"genre:schlager year:{year}", "type": "track", "limit": 50},
    )
    data = response.json()
    tracks = [
        {
            "name": track["name"],
            "artist": ", ".join(artist["name"] for artist in track["artists"]),
            "popularity": track["popularity"],
            "release_date": track["album"]["release_date"],
        }
        for track in data["tracks"]["items"]
    ]
    return tracks

# Collect tracks from 2008 (spotify launched that year) to 2024
all_tracks = []
for year in range(2008, 2025):
    print(f"Fetching Schlager tracks for {year}...")
    all_tracks.extend(get_schlager_tracks_by_year(year))

# Save results or analyze
print(f"Collected {len(all_tracks)} tracks.")
# Out:
# Fetching Schlager tracks for 2008...
# Fetching Schlager tracks for 2009...
# Fetching Schlager tracks for 2010...
# Fetching Schlager tracks for 2011...
# Fetching Schlager tracks for 2012...
# Fetching Schlager tracks for 2013...
# Fetching Schlager tracks for 2014...
# Fetching Schlager tracks for 2015...
# Fetching Schlager tracks for 2016...
# Fetching Schlager tracks for 2017...
# Fetching Schlager tracks for 2018...
# Fetching Schlager tracks for 2019...
# Fetching Schlager tracks for 2020...
# Fetching Schlager tracks for 2021...
# Fetching Schlager tracks for 2022...
# Fetching Schlager tracks for 2023...
# Fetching Schlager tracks for 2024...
# Collected 850 tracks.

# %% [markdown]
# ### Displaying the Schlager Tracks

# %%
# Display the first 10 tracks
for track in all_tracks[:10]:
    print(track)
# Out:
# {'name': 'Sweet Caroline - Single Version', 'artist': 'DJ Ötzi', 'popularity': 57, 'release_date': '2008'}
# {'name': 'Ein Bett Im Kornfeld', 'artist': 'Jürgen Drews', 'popularity': 53, 'release_date': '2008-10-17'}
# {'name': '1000 und 1 Nacht - Remastered 2008', 'artist': 'Klaus Lage', 'popularity': 55, 'release_date': '2008-01-01'}
# {'name': 'Eine neue Liebe ist wie ein neues Leben', 'artist': 'Jürgen Marcus', 'popularity': 51, 'release_date': '2008-10-11'}
# {'name': 'Irgendwann, Irgendwo, Irgendwie', 'artist': 'Jürgen Drews', 'popularity': 46, 'release_date': '2008-10-17'}
# {'name': 'Ich fang dir den Mond', 'artist': 'Andreas Martin', 'popularity': 44, 'release_date': '2008-05-16'}
# {'name': 'Noch in 100.000 Jahren - Single Version', 'artist': 'DJ Ötzi', 'popularity': 41, 'release_date': '2008'}
# {'name': 'Es ist Weihnachtszeit', 'artist': 'Nik P.', 'popularity': 38, 'release_date': '2008-11-07'}
# {'name': 'Sie vergass zu verzeihn - Radio', 'artist': 'Christian Lais', 'popularity': 40, 'release_date': '2008-02-20'}
# {'name': 'Wir sind alle über 40 - Originalversion', 'artist': 'Brunner & Brunner', 'popularity': 38, 'release_date': '2008-04-18'}

# %%
import pandas as pd

# Convert the list of dictionaries to a DataFrame
spotify_data_schlager_over_time = pd.DataFrame(all_tracks)

# Display the first few rows
spotify_data_schlager_over_time.head()
# Out:
#                                       name         artist  popularity  \
# 0          Sweet Caroline - Single Version        DJ Ötzi          57
# 1                     Ein Bett Im Kornfeld   Jürgen Drews          53
# 2       1000 und 1 Nacht - Remastered 2008     Klaus Lage          55
# 3  Eine neue Liebe ist wie ein neues Leben  Jürgen Marcus          51
# 4          Irgendwann, Irgendwo, Irgendwie   Jürgen Drews          46
#
#   release_date
# 0         2008
# 1   2008-10-17
# 2   2008-01-01
# 3   2008-10-11
# 4   2008-10-17

# %% [markdown]
# ### Statiscal Variables for the popularity index of Spotify

# %%
spotify_data_schlager_over_time.describe()
# Out:
#        popularity
# count  850.000000
# mean    38.110588
# std      8.331161
# min     14.000000
# 25%     32.000000
# 50%     38.000000
# 75%     44.000000
# max     64.000000

# %% [markdown]
# ### Metadata for Schlager Tracks

# %%
spotify_data_schlager_over_time.head()
# Out:
#                                       name         artist  popularity  \
# 0          Sweet Caroline - Single Version        DJ Ötzi          57
# 1                     Ein Bett Im Kornfeld   Jürgen Drews          53
# 2       1000 und 1 Nacht - Remastered 2008     Klaus Lage          55
# 3  Eine neue Liebe ist wie ein neues Leben  Jürgen Marcus          51
# 4          Irgendwann, Irgendwo, Irgendwie   Jürgen Drews          46
#
#   release_date
# 0         2008
# 1   2008-10-17
# 2   2008-01-01
# 3   2008-10-11
# 4   2008-10-17

# %%
# Check rows where the release_date couldn't be parsed
print(spotify_data_schlager_over_time[spotify_data_schlager_over_time["release_date"].isna()])

# Apply this function to detect years (4-digit format) and convert them into complete dates
def fix_incomplete_dates(x):
    x = str(x)
    if len(x) == 4 and x.isdigit():  # Check if the value is a year
        return x + "-01-01"  # Add a default month and day
    return x  # Return the date as it is if it's not just a year

# Apply this function to the release_date column
spotify_data_schlager_over_time["release_date"] = spotify_data_schlager_over_time["release_date"].apply(fix_incomplete_dates)

# Convert the release_date to datetime again
spotify_data_schlager_over_time["release_date"] = pd.to_datetime(spotify_data_schlager_over_time["release_date"], errors="coerce")

# Extract the release year
spotify_data_schlager_over_time["release_year"] = spotify_data_schlager_over_time["release_date"].dt.year.astype("Int64")

# Display the cleaned DataFrame
spotify_data_schlager_over_time.head()
# Out:
# Empty DataFrame
# Columns: [name, artist, popularity, release_date]
# Index: []
#                                       name         artist  popularity  \
# 0          Sweet Caroline - Single Version        DJ Ötzi          57
# 1                     Ein Bett Im Kornfeld   Jürgen Drews          53
# 2       1000 und 1 Nacht - Remastered 2008     Klaus Lage          55
# 3  Eine neue Liebe ist wie ein neues Leben  Jürgen Marcus          51
# 4          Irgendwann, Irgendwo, Irgendwie   Jürgen Drews          46
#
#   release_date  release_year
# 0   2008-01-01          2008
# 1   2008-10-17          2008
# 2   2008-01-01          2008
# 3   2008-10-11          2008
# 4   2008-10-17          2008

# %%
tracks_in_2020 = spotify_data_schlager_over_time[spotify_data_schlager_over_time["release_year"] == 2020]
print(tracks_in_2020)
# Out:
#                                                   name  \
# 600              Wegen Dir (Nachts wenn alles schläft)
# 601                                    Es ist die Zeit
# 602          Ich hab' geträumt von dir (2020 Remaster)
# 603                                Traktorführerschein
# 604                                          Difigiano
# 605                                 Dein Herz verliert
# 606  Der hellste Stern (Böhmischer Traum) - Silverj...
# 607                                    One Night Stand
# 608  Der hellste Stern (Böhmischer Traum) - Silverj...
# 609                Ich muss Dir was sagen - Single Mix
# 610          1000 Träume weit (Torneró) - Version 2020
# 611                                 Der geilste Fehler
# 612                                     Lederhosenrock
# 613              Wegen Dir (Nachts wenn alles schläft)
# 614                 Ich will mit dir (nicht nur reden)
# 615                                              Marie
# 616                                   Blödsinn im Kopf
# 617                            Ich bau dir ein Schloss
# 618                                         Eine Nacht
# 619                I mog di so - Xtreme Sound Partymix
# 620                                    War's das schon
# 621                 Auf der Vogelwiese - Silverjam Mix
# 622                                It's Christmas Time
# 623                                    Das kann ich ab
# 624                                        Party Mix I
# 625                                 Wir leben Schlager
# 626                                     Last Christmas
# 627                                  Engelbert Strauss
# 628                         Und brennen 100.000 Kerzen
# 629                                            Weekend
# 630                    Ich fahr Weihnachten nach Hause
# 631                                             G'fühl
# 632                          Versuch's nochmal mit mir
# 633                         Driving Home For Christmas
# 634                                      VORBEI VORBEI
# 635                            Es wird scho glei dumpa
# 636                           Gemeinsam niemals einsam
# 637                           Wie frei willst du sein?
# 638                                         Spinnst du
# 639                                               Bunt
# 640                                               LEB!
# 641                    Kling Glöckchen Klingelingeling
# 642                                            Absolut
# 643                                Weil ich dich liebe
# 644          1000 Träume weit (Torneró) - Version 2020
# 645                                     Der Sensenmann
# 646  Sie hat es wieder getan (feat. Florian Silbere...
# 647                                    White Christmas
# 648                          Alles nochmal - X-Mas Mix
# 649                                      VORBEI VORBEI
#
#                                                 artist  popularity  \
# 600                     Kerstin Ott, Howard Carpendale          53
# 601                                   Andreas Gabalier          47
# 602                                      Matthias Reim          55
# 603                                Melissa Naschenweng          42
# 604                                Melissa Naschenweng          42
# 605                                Melissa Naschenweng          38
# 606                                            DJ Ötzi          43
# 607                                        Marina Marx          45
# 608                                            DJ Ötzi          41
# 609                                        Kerstin Ott          43
# 610                              Anna-Maria Zimmermann          44
# 611                                        Marina Marx          43
# 612                                Melissa Naschenweng          33
# 613                     Kerstin Ott, Howard Carpendale          42
# 614                                      Sonia Liebing          41
# 615                                    Die Draufgänger          45
# 616                                Melissa Naschenweng          32
# 617                        Jürgen Drews, Matthias Reim          41
# 618                                      Ramon Roselly          42
# 619                             voXXclub, Xtreme Sound          38
# 620                                             Nockis          30
# 621                                voXXclub, SILVERJAM          40
# 622                                   Andreas Gabalier          39
# 623                                     Christin Stark          39
# 624                                                Pur          48
# 625  Jürgen Drews, Ben Zucker, Kerstin Ott, Matthia...          42
# 626                     Andreas Gabalier, Gregor Meyle          34
# 627                                         Dorfrocker          40
# 628                 Thomas Anders, Florian Silbereisen          41
# 629                          DJ Herzbeat, Sarah Engels          41
# 630                                            Fantasy          41
# 631                                Melissa Naschenweng          29
# 632                 Thomas Anders, Florian Silbereisen          39
# 633                                   Andreas Gabalier          35
# 634                                           Michelle          38
# 635                                   Andreas Gabalier          33
# 636                 Thomas Anders, Florian Silbereisen          38
# 637  Howard Carpendale, Royal Philharmonic Orchestr...          37
# 638                                     Christin Stark          37
# 639                                      Beatrice Egli          39
# 640                                            DJ Ötzi          37
# 641                                            Fantasy          38
# 642                                      Sonia Liebing          37
# 643                                     Sarah Schiffer          36
# 644                              Anna-Maria Zimmermann          37
# 645                                Melissa Naschenweng          27
# 646                 Thomas Anders, Florian Silbereisen          38
# 647                                   Andreas Gabalier          32
# 648                                      Sonia Liebing          37
# 649                                           Michelle          36
#
#     release_date  release_year
# 600   2020-09-18          2020
# 601   2020-11-20          2020
# 602   2020-07-31          2020
# 603   2020-10-30          2020
# 604   2020-10-30          2020
# 605   2020-10-30          2020
# 606   2020-01-10          2020
# 607   2020-07-24          2020
# 608   2020-03-13          2020
# 609   2020-09-18          2020
# 610   2020-10-23          2020
# 611   2020-07-24          2020
# 612   2020-10-30          2020
# 613   2020-01-10          2020
# 614   2020-09-25          2020
# 615   2020-08-28          2020
# 616   2020-10-30          2020
# 617   2020-10-23          2020
# 618   2020-04-09          2020
# 619   2020-09-18          2020
# 620   2020-06-19          2020
# 621   2020-09-18          2020
# 622   2020-11-20          2020
# 623   2020-06-05          2020
# 624   2020-10-23          2020
# 625   2020-10-23          2020
# 626   2020-11-20          2020
# 627   2020-10-02          2020
# 628   2020-10-16          2020
# 629   2020-06-12          2020
# 630   2020-11-20          2020
# 631   2020-10-30          2020
# 632   2020-06-05          2020
# 633   2020-11-20          2020
# 634   2020-10-23          2020
# 635   2020-11-20          2020
# 636   2020-10-16          2020
# 637   2020-10-23          2020
# 638   2020-06-05          2020
# 639   2020-07-24          2020
# 640   2020-10-23          2020
# 641   2020-11-20          2020
# 642   2020-09-25          2020
# 643   2020-04-03          2020
# 644   2020-03-06          2020
# 645   2020-10-30          2020
# 646   2020-06-05          2020
# 647   2020-11-20          2020
# 648   2020-11-13          2020
# 649   2020-10-02          2020

# %% [markdown]
# 3. Popularity Score
#
# This will provide the popularity score of each track, which reflects how well the track is performing (related to streams but not the exact count).
# #Artist & Track Data: You’ll also get the artist name, track name, and release year.
# #The popularity score provided by Spotify is a useful proxy for analyzing how the popularity of a genre, artist, or track has evolved over time.
# #While it doesn’t give you raw stream counts, the popularity score (ranging from 0 to 100) is closely tied to listener engagement, including streams, playlist inclusions, and radio plays.
# #Limitations:
# #the popularity score does not directly represent streams and can be influenced by factors such as playlist inclusion, recent plays, and algorithmic boosting.
# #Popularity may skew towards newer tracks due to recency bias in Spotify’s algorithm.

# %%
#calcuate popularity mean over years
mean_popularity_per_year = spotify_data_schlager_over_time.groupby("release_year")["popularity"].mean()
print(mean_popularity_per_year)

#calculate highest mean popularity score and highest popularity year:
highest_popularity_year = mean_popularity_per_year.idxmax()
highest_mean_popularity = mean_popularity_per_year.max()

print(f"The highest popularity score: {highest_mean_popularity} is in year: {highest_popularity_year}")

#show the most popular tracks in the highest popularity year:
most_popular_tracks_in_highest_year = spotify_data_schlager_over_time[df_schlager["release_year"] == highest_popularity_year]
print("Tracks contributing to high popularity in this year:")
print(most_popular_tracks_in_highest_year)
# Out:
# release_year
# 2008    33.64
# 2009    33.04
# 2010    36.20
# 2011    33.42
# 2012    29.76
# 2013    35.06
# 2014    32.74
# 2015    35.12
# 2016    37.12
# 2017    39.58
# 2018    38.84
# 2019    37.30
# 2020    39.30
# 2021    41.12
# 2022    38.90
# 2023    42.22
# 2024    45.10
# Name: popularity, dtype: float64
# The highest popularity score: 45.1 is in year: 2024
# Tracks contributing to high popularity in this year:
#                                                   name  \
# 800                                         Handwerker
# 801                                  Hallo kleine Maus
# 802                                  Ich werde da sein
# 803                     Aperol Spritz - Techno Version
# 804                       Wer lieben will, muss fühlen
# 805                            Es ist einfach passiert
# 806                                 Das ist nicht fair
# 807                                      Bock auf Bier
# 808                                      Aperol Spritz
# 809                             Willst du mit mir gehn
# 810                                       MALLE BEREIT
# 811           Ganz oder gar nicht (sicher nicht Paris)
# 812                             Immer immer wieder tun
# 813                                Michl mit der Sichl
# 814                              Himbeerrot (One Kiss)
# 815                                           Legenden
# 816                                          Für immer
# 817                          Dann leg ich Schlager auf
# 818                                           Exklusiv
# 819         Warum hast Du nicht nein gesagt - Club Mix
# 820                                  Die Liebe gewinnt
# 821                                   Magische Momente
# 822  Spieglein, Spieglein an der Wand - Stereoact R...
# 823                              Mit den Füßen im Meer
# 824                                         Heartbreak
# 825                                             Sophie
# 826                   So ein schöner Tag (Fliegerlied)
# 827                                        Nein, Baby!
# 828               Hallo, hallo, schön, dass du da bist
# 829                              Alte Liebe rostet nie
# 830                                 Fünf kleine Fische
# 831                            Es ist einfach passiert
# 832                                    Lass mich gehen
# 833                                    Sag niemals nie
# 834                                     Mein Geheimnis
# 835                        Marie, ich vergess dich nie
# 836                                         Du, Du, Du
# 837                        Lieb mich oder lass es sein
# 838                                         RESPEKTLOS
# 839                                    Sag niemals nie
# 840                              Alte Liebe rostet nie
# 841                                Sommernachtsgefühle
# 842                                               Echo
# 843                                    Ich wünsche dir
# 844                                               Pink
# 845                                            Mit Dir
# 846                                     Tschu Tschu wa
# 847                                     Alles und mehr
# 848                      Warum hast du nicht ja gesagt
# 849                                         Aramsamsam
#
#                                                 artist  popularity  \
# 800                       Mickie Krause, Julian Sommer          59
# 801                            Die Draufgänger, Hannah          48
# 802                                      Roland Kaiser          53
# 803  Vincent Gross, Beats by Luca, Aditotoro, paulomuc          48
# 804                                        Maite Kelly          50
# 805                                        Maite Kelly          50
# 806                                        Andrea Berg          50
# 807                       Mickie Krause, Lorenz Büffel          52
# 808                                      Vincent Gross          49
# 809                             Nino de Angelo, Jenice          48
# 810                  Mia Julia, MAKZ 38, MartinBepunkt          52
# 811                                        Kerstin Ott          49
# 812                                      Beatrice Egli          49
# 813                                Melissa Naschenweng          38
# 814                                        Vanessa Mai          49
# 815                                Melissa Naschenweng          37
# 816                                       Sarah Engels          48
# 817                          Mickie Krause, Tim Toupet          49
# 818                                       Semino Rossi          44
# 819                         Roland Kaiser, Maite Kelly          46
# 820                             DJ Herzbeat, Neonlicht          46
# 821                                       Semino Rossi          42
# 822                                     Stereoact, Ibo          46
# 823                                             Nik P.          39
# 824                                         Marie Reim          45
# 825                                    Die Draufgänger          40
# 826                                     Helene Fischer          47
# 827                                      Sonia Liebing          45
# 828                                     Helene Fischer          46
# 829                                        Kerstin Ott          44
# 830                                     Helene Fischer          45
# 831                                        Maite Kelly          43
# 832                                     Christin Stark          45
# 833                                        Andrea Berg          44
# 834                                      Roland Kaiser          48
# 835                                             Nockis          32
# 836                                      Beatrice Egli          43
# 837                                           Michelle          43
# 838                                          Mia Julia          47
# 839                                        Andrea Berg          42
# 840                                        Kerstin Ott          43
# 841                                Florian Silbereisen          43
# 842                                           voXXclub          41
# 843                                      Sonia Liebing          42
# 844                                   Vanessa Mai, HBz          46
# 845                                       Sarah Engels          44
# 846                                     Helene Fischer          42
# 847                       Die Paldauer, Tiroler Schmäh          29
# 848                                      Norman Langen          43
# 849                                     Helene Fischer          42
#
#     release_date  release_year  mean_popularity_per_year
# 800   2024-05-03          2024                      45.1
# 801   2024-04-26          2024                      45.1
# 802   2024-10-04          2024                      45.1
# 803   2024-06-28          2024                      45.1
# 804   2024-03-28          2024                      45.1
# 805   2024-03-28          2024                      45.1
# 806   2024-10-18          2024                      45.1
# 807   2024-07-12          2024                      45.1
# 808   2024-05-24          2024                      45.1
# 809   2024-08-23          2024                      45.1
# 810   2024-04-05          2024                      45.1
# 811   2024-10-18          2024                      45.1
# 812   2024-10-11          2024                      45.1
# 813   2024-08-23          2024                      45.1
# 814   2024-09-06          2024                      45.1
# 815   2024-05-31          2024                      45.1
# 816   2024-03-22          2024                      45.1
# 817   2024-09-06          2024                      45.1
# 818   2024-09-06          2024                      45.1
# 819   2024-06-20          2024                      45.1
# 820   2024-06-28          2024                      45.1
# 821   2024-09-06          2024                      45.1
# 822   2024-04-05          2024                      45.1
# 823   2024-05-03          2024                      45.1
# 824   2024-08-09          2024                      45.1
# 825   2024-09-20          2024                      45.1
# 826   2024-11-01          2024                      45.1
# 827   2024-08-02          2024                      45.1
# 828   2024-11-01          2024                      45.1
# 829   2024-01-12          2024                      45.1
# 830   2024-11-01          2024                      45.1
# 831   2024-03-08          2024                      45.1
# 832   2024-05-03          2024                      45.1
# 833   2024-06-07          2024                      45.1
# 834   2024-06-21          2024                      45.1
# 835   2024-06-14          2024                      45.1
# 836   2024-01-05          2024                      45.1
# 837   2024-07-05          2024                      45.1
# 838   2024-08-23          2024                      45.1
# 839   2024-10-18          2024                      45.1
# 840   2024-10-18          2024                      45.1
# 841   2024-06-07          2024                      45.1
# 842   2024-10-04          2024                      45.1
# 843   2024-04-05          2024                      45.1
# 844   2024-05-02          2024                      45.1
# 845   2024-08-30          2024                      45.1
# 846   2024-11-01          2024                      45.1
# 847   2024-07-12          2024                      45.1
# 848   2024-07-12          2024                      45.1
# 849   2024-11-01          2024                      45.1

# %% [markdown]
# we see that the popularity mean score is the same over all the artist and tracks in 2024
#
# now we look at the top 50 artist with the highest populairty score:

# %%
top_50 = spotify_data_schlager_over_time.sort_values(by="popularity", ascending=False).head(50)

print("Top 50:")
print(top_50[["name", "artist", "popularity", "release_year"]])

#top 10:
top_10 = spotify_data_schlager_over_time.sort_values(by="popularity", ascending=False).head(10)

print("\n Top 10:")
print(top_10[["name", "artist", "popularity", "release_year"]])
# Out:
# Top 50:
#                                                   name  \
# 250                            Atemlos durch die Nacht
# 800                                         Handwerker
# 350                                           Hulapalu
# 450                                          Herzbeben
# 12                                      La Vie en rose
# 50       Ich will immer wieder... dieses Fieber spür'n
# 700   Der Zug hat keine Bremse - Mallorcastyle Edition
# 100                               Idiot - Version 2011
# 500                                   Regenbogenfarben
# 101                         1000 Träume weit (Tornero)
# 602          Ich hab' geträumt von dir (2020 Remaster)
# 0                      Sweet Caroline - Single Version
# 519                                             Moskau
# 502               Was für eine geile Zeit - Single Mix
# 106                               Hey Baby (Radio Mix)
# 102                               I sing a Liad für di
# 501                                     Nicht verdient
# 400                              Sieben Leben für dich
# 751  Atemlos durch die Nacht - 10 Year Anniversary ...
# 802                                  Ich werde da sein
# 600              Wegen Dir (Nachts wenn alles schläft)
# 503                              Heute Nacht für immer
# 452                                         Achterbahn
# 750               Ein bisschen Aroma - Stereoact Remix
# 755                              Bring mich nach Hause
# 300         Warum hast Du nicht nein gesagt - Club Mix
# 146                                           Wahnsinn
# 251                                          Mein Herz
# 650             Ich liebe das Leben - Stereoact #Remix
# 110                       Sweet Caroline - Party Remix
# 807                                      Bock auf Bier
# 754  Verlieben, verloren, vergessen, verzeih'n - HB...
# 810                                       MALLE BEREIT
# 2                   1000 und 1 Nacht - Remastered 2008
# 255                                            Oh Baby
# 252                                  Mit keinem Andern
# 451                      A Mann für Amore - Single Mix
# 752                         Du (Was ich will, bist du)
# 104                                 Du bist mein Glück
# 753                                               Ouzo
# 757                              Bring mich nach Hause
# 653                                       Null auf 100
# 509                                           Na und?!
# 552                                    Eine Woche wach
# 654  Küss mich, halt mich, lieb mich - Drei Haselnü...
# 455                                        Nur mit Dir
# 806                                 Das ist nicht fair
# 804                       Wer lieben will, muss fühlen
# 805                            Es ist einfach passiert
# 256                                     Einsamer Stern
#
#                                    artist  popularity  release_year
# 250                        Helene Fischer          61          2013
# 800          Mickie Krause, Julian Sommer          59          2024
# 350                      Andreas Gabalier          58          2015
# 450                        Helene Fischer          58          2017
# 12                             Édith Piaf          57          2008
# 50                         Helene Fischer          57          2009
# 700  Mia Julia, Malle Anja, Lorenz Büffel          57          2022
# 100               Michelle, Matthias Reim          57          2010
# 500           Kerstin Ott, Helene Fischer          57          2018
# 101                 Anna-Maria Zimmermann          57          2010
# 602                         Matthias Reim          55          2020
# 0                                 DJ Ötzi          55          2008
# 519                       Dschinghis Khan          55          2018
# 502                            Ben Zucker          55          2018
# 106                               DJ Ötzi          54          2010
# 102                      Andreas Gabalier          54          2010
# 501               Michelle, Matthias Reim          54          2018
# 400                           Maite Kelly          54          2016
# 751          Helene Fischer, Shirin David          54          2023
# 802                         Roland Kaiser          53          2024
# 600        Kerstin Ott, Howard Carpendale          53          2020
# 503                           Maite Kelly          53          2018
# 452                        Helene Fischer          53          2017
# 750            Roger Whittaker, Stereoact          53          2023
# 755                             Mia Julia          53          2023
# 300            Roland Kaiser, Maite Kelly          53          2014
# 146                        Wolfgang Petry          53          2010
# 251                         Beatrice Egli          53          2013
# 650             Vicky Leandros, Stereoact          52          2021
# 110                               DJ Ötzi          52          2010
# 807          Mickie Krause, Lorenz Büffel          52          2024
# 754                   Wolfgang Petry, HBz          52          2023
# 810     Mia Julia, MAKZ 38, MartinBepunkt          52          2024
# 2                              Klaus Lage          52          2008
# 255                             Mia Julia          52          2013
# 252                        Helene Fischer          52          2013
# 451                               DJ Ötzi          51          2017
# 752                               DJ Ötzi          51          2023
# 104                         Matthias Reim          51          2010
# 753                         Vincent Gross          51          2023
# 757                             Mia Julia          51          2023
# 653                        Helene Fischer          51          2021
# 509                            Ben Zucker          50          2018
# 552                         Mickie Krause          50          2019
# 654                          Ella Endlich          50          2021
# 455                        Helene Fischer          50          2017
# 806                           Andrea Berg          50          2024
# 804                           Maite Kelly          50          2024
# 805                           Maite Kelly          50          2024
# 256                         Matthias Reim          50          2013
#
#  Top 10:
#                                                  name  \
# 250                           Atemlos durch die Nacht
# 800                                        Handwerker
# 350                                          Hulapalu
# 450                                         Herzbeben
# 12                                     La Vie en rose
# 50      Ich will immer wieder... dieses Fieber spür'n
# 700  Der Zug hat keine Bremse - Mallorcastyle Edition
# 100                              Idiot - Version 2011
# 500                                  Regenbogenfarben
# 101                        1000 Träume weit (Tornero)
#
#                                    artist  popularity  release_year
# 250                        Helene Fischer          61          2013
# 800          Mickie Krause, Julian Sommer          59          2024
# 350                      Andreas Gabalier          58          2015
# 450                        Helene Fischer          58          2017
# 12                             Édith Piaf          57          2008
# 50                         Helene Fischer          57          2009
# 700  Mia Julia, Malle Anja, Lorenz Büffel          57          2022
# 100               Michelle, Matthias Reim          57          2010
# 500           Kerstin Ott, Helene Fischer          57          2018
# 101                 Anna-Maria Zimmermann          57          2010

# %% [markdown]
# ## 4. Visualization

# %% [markdown]
# ### Top 10 Schlager Tracks by Popularity

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12, 6))

#list of colors
colors = plt.cm.viridis(np.linspace(0, 1, len(top_10)))  # Using the "viridis" colormap

# Plot horizontal bar chart with different colors for each track
plt.barh(
    top_10["name"] + " by " + top_10["artist"] + " (" + top_10["release_year"].astype(str) + ")",
    top_10["popularity"],
    color=colors  
)

plt.title("Top 10 Schlager Tracks by Popularity", fontsize=14)
plt.xlabel("Popularity Score", fontsize=12)
plt.ylabel("Track (Release Year)", fontsize=12)
plt.gca().invert_yaxis()  # Invert to have the highest score on top
plt.tight_layout()


#save as pdf for poster use:
plt.savefig("data/Top 10 Schlager Tracks by Popularity.pdf")

plt.show()

# %% [markdown]
# ### visualize the average (mean) popularity of schlager over time

# %%
#visualize the average (mean) popularity of schlager over time
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
mean_popularity_per_year.plot(kind='line', marker='o') #variable from above 
plt.title('Average Popularity of Schlager Over Time')
plt.xlabel('Release Year')
plt.ylabel('Mean Popularity')
plt.grid()

#save figure:
plt.savefig("data/Average Popularity of Schlager over Time.pdf", format = "pdf")

plt.show()

# %% [markdown]
# ### #artists/tracks with the highest average popularity of every year:

# %%
#artists/tracks with the highest average popularity of every year:
most_popular_tracks = spotify_data_schlager_over_time.loc[spotify_data_schlager_over_time.groupby("release_year")["popularity"].idxmax()]
print(most_popular_tracks)
# Out:
#                                                   name  \
# 12                                      La Vie en rose
# 50       Ich will immer wieder... dieses Fieber spür'n
# 100                               Idiot - Version 2011
# 152                              Die Hölle morgen früh
# 204                100.000 leuchtende Sterne - Clubmix
# 250                            Atemlos durch die Nacht
# 300         Warum hast Du nicht nein gesagt - Club Mix
# 350                                           Hulapalu
# 400                              Sieben Leben für dich
# 450                                          Herzbeben
# 500                                   Regenbogenfarben
# 552                                    Eine Woche wach
# 602          Ich hab' geträumt von dir (2020 Remaster)
# 650             Ich liebe das Leben - Stereoact #Remix
# 700   Der Zug hat keine Bremse - Mallorcastyle Edition
# 751  Atemlos durch die Nacht - 10 Year Anniversary ...
# 800                                         Handwerker
#
#                                    artist  popularity release_date  \
# 12                             Édith Piaf          57   2008-10-13
# 50                         Helene Fischer          57   2009-01-01
# 100               Michelle, Matthias Reim          57   2010-11-19
# 152                        Helene Fischer          49   2011-01-01
# 204                 Anna-Maria Zimmermann          45   2012-01-01
# 250                        Helene Fischer          61   2013-01-01
# 300            Roland Kaiser, Maite Kelly          53   2014-09-12
# 350                      Andreas Gabalier          58   2015-05-15
# 400                           Maite Kelly          54   2016-10-14
# 450                        Helene Fischer          58   2017-05-12
# 500           Kerstin Ott, Helene Fischer          57   2018-08-17
# 552                         Mickie Krause          50   2019-05-10
# 602                         Matthias Reim          55   2020-07-31
# 650             Vicky Leandros, Stereoact          52   2021-01-01
# 700  Mia Julia, Malle Anja, Lorenz Büffel          57   2022-06-24
# 751          Helene Fischer, Shirin David          54   2023-11-24
# 800          Mickie Krause, Julian Sommer          59   2024-05-03
#
#      release_year  mean_popularity_per_year
# 12           2008                     33.64
# 50           2009                     33.04
# 100          2010                     36.20
# 152          2011                     33.42
# 204          2012                     29.76
# 250          2013                     35.06
# 300          2014                     32.74
# 350          2015                     35.12
# 400          2016                     37.12
# 450          2017                     39.58
# 500          2018                     38.84
# 552          2019                     37.30
# 602          2020                     39.30
# 650          2021                     41.12
# 700          2022                     38.90
# 751          2023                     42.22
# 800          2024                     45.10

# %% [markdown]
# ### for consistency in popularity calculate variance
# ### visualize the popularity variance and see how it develops over the years (2008 - 2024):

# %%
#for consistency in popularity calculate variance:
popularity_variance = spotify_data_schlager_over_time.groupby("release_year")["popularity"].std()
print(popularity_variance)

#visualize the popularity variance and see how it develops over the years (2008 - 2024):
plt.figure(figsize=(10, 6))
popularity_variance.plot(kind='line', color = "red",  marker='x') #variable from above 
plt.title('(Popularity) Variance of Schlager Over Time')
plt.xlabel('Release Year')
plt.ylabel("(Popularity) Variance")
plt.grid()


#save figure:
plt.savefig("data/(Popularity) Variance of Schlager Over Time.pdf")

plt.show()
# Out:
# release_year
# 2008    8.845061
# 2009    6.493199
# 2010    8.985249
# 2011    7.743569
# 2012    7.484842
# 2013    9.896217
# 2014    7.917457
# 2015    7.723909
# 2016    7.212914
# 2017    7.145971
# 2018    8.809457
# 2019    7.048665
# 2020    5.330888
# 2021    4.880783
# 2022    5.863237
# 2023    6.007784
# 2024    5.067906
# Name: popularity, dtype: float64

# %% [markdown]
# **Interpretation of variance:**
#
# 2013 (9.90), 2008 (8.85), and 2010 (8.99) have the highest standard deviations.
# This means that in these years, there was a wider range of popularity scores for tracks.
# There may have been some tracks with significantly higher popularity and some with much lower popularity compared to the average for that year.
#
# 2021 (4.88), 2020 (5.33), and 2024 (5.07) have the lowest standard deviations.
# This suggests that the popularity of tracks in these years was more consistent, with less variation between the highest and lowest scores.

# %%
#artist with the most tracks over the years:
artist_track_count = spotify_data_schlager_over_time.groupby('artist')['name'].count()
top_artists = artist_track_count.sort_values(ascending=False).head(10)
print(top_artists)
# Out:
# artist
# Helene Fischer         52
# Andreas Gabalier       48
# Melissa Naschenweng    31
# Nockis                 27
# Udo Jürgens            26
# Roland Kaiser          26
# Nik P.                 23
# DJ Ötzi                22
# Maite Kelly            19
# Andrea Berg            19
# Name: name, dtype: int64

# %% [markdown]
# correlation between release year and popularity

# %%
#correlation between release year and popularity 
correlation = spotify_data_schlager_over_time['release_year'].corr(spotify_data_schlager_over_time['popularity'])
print(f"Correlation between release year and popularity: {correlation}")
# Out:
# Correlation between release year and popularity: 0.3982197954251148

# %% [markdown]
# ### The most popular Schlager Tracks

# %%
spotify_data_schlager_over_time.head(26)
# Out:
#                                        name  \
# 0           Sweet Caroline - Single Version
# 1                      Ein Bett Im Kornfeld
# 2        1000 und 1 Nacht - Remastered 2008
# 3   Eine neue Liebe ist wie ein neues Leben
# 4           Irgendwann, Irgendwo, Irgendwie
# 5                     Ich fang dir den Mond
# 6           Sie vergass zu verzeihn - Radio
# 7                     Es ist Weihnachtszeit
# 8   Noch in 100.000 Jahren - Single Version
# 9   Wir sind alle über 40 - Originalversion
# 10                       Jan Pillemann Otze
# 11                           Tausend Frauen
# 12                           La Vie en rose
# 13                     Heissgeliebt - Radio
# 14                         Mal ganz ehrlich
# 15            Dieses Parfüm auf deiner Haut
# 16               Amsterdam - Single Version
# 17                             Sternenstaub
# 18                     Küss mich, Küss mich
# 19                                     Lena
# 20                     7 Sünden - Party Mix
# 21        Faust auf Faust - Remastered 2008
# 22                  Sie liebt den DJ - 2004
# 23            Weihnachten steht vor der Tür
# 24                              Hotel Engel
# 25                                   Tränen
#
#                                     artist  popularity release_date  \
# 0                                  DJ Ötzi          55   2008-01-01
# 1                             Jürgen Drews          49   2008-10-17
# 2                               Klaus Lage          52   2008-01-01
# 3                            Jürgen Marcus          48   2008-10-11
# 4                             Jürgen Drews          45   2008-10-17
# 5                           Andreas Martin          42   2008-05-16
# 6                           Christian Lais          40   2008-02-20
# 7                                   Nik P.          37   2008-11-07
# 8                                  DJ Ötzi          39   2008-01-01
# 9                        Brunner & Brunner          37   2008-04-18
# 10                           Mickie Krause          43   2008-01-01
# 11                            Claudia Jung          33   2008-01-01
# 12                              Édith Piaf          57   2008-10-13
# 13                          Christian Lais          34   2008-02-20
# 14                          Helene Fischer          34   2008-01-01
# 15                          Andrea Jürgens          34   2008-01-01
# 16  Axel Fischer, Cora Von dem Bottlenberg          41   2008-10-31
# 17                            Marc Pircher          28   2008-01-01
# 18                           Kristina Bach          30   2008-06-27
# 19                           G.G. Anderson          27   2008-01-01
# 20                   DJ Ötzi, Marc Pircher          35   2008-01-01
# 21                              Klaus Lage          44   2008-01-01
# 22                         Michael Wendler          37   2008-07-25
# 23                               Andy Borg          31   2008-10-31
# 24                                 DJ Ötzi          30   2008-01-01
# 25                      DJ Ötzi, Kate Hall          25   2008-01-01
#
#     release_year  mean_popularity_per_year
# 0           2008                     33.64
# 1           2008                     33.64
# 2           2008                     33.64
# 3           2008                     33.64
# 4           2008                     33.64
# 5           2008                     33.64
# 6           2008                     33.64
# 7           2008                     33.64
# 8           2008                     33.64
# 9           2008                     33.64
# 10          2008                     33.64
# 11          2008                     33.64
# 12          2008                     33.64
# 13          2008                     33.64
# 14          2008                     33.64
# 15          2008                     33.64
# 16          2008                     33.64
# 17          2008                     33.64
# 18          2008                     33.64
# 19          2008                     33.64
# 20          2008                     33.64
# 21          2008                     33.64
# 22          2008                     33.64
# 23          2008                     33.64
# 24          2008                     33.64
# 25          2008                     33.64

# %% [markdown]
# ### DataFrame with multiple artists per track

# %%
import pandas as pd
import networkx as nx
from itertools import combinations

# Assuming spotify_data_schlager_over_time is your DataFrame
# Filter for rows where there are multiple artists (if applicable)

# Example: DataFrame with multiple artists per track
tracks_with_multiple_artists = spotify_data_schlager_over_time[spotify_data_schlager_over_time['name'].duplicated(keep=False)]

# Create an empty graph
G = nx.Graph()

# For each track with multiple artists, create all pairs of artists
for track in tracks_with_multiple_artists['name'].unique():
    artists_in_track = spotify_data_schlager_over_time[spotify_data_schlager_over_time['name'] == track]['artist'].values
    for artist1, artist2 in combinations(artists_in_track, 2):
        if G.has_edge(artist1, artist2):
            G[artist1][artist2]['weight'] += 1  # If they already have an edge, increase the weight (collaborations)
        else:
            G.add_edge(artist1, artist2, weight=1)  # Add a new edge with weight 1 (first collaboration)

# Check the created network
print(G.nodes())  # Artists as nodes
print(G.edges())  # Collaborations as edges

# Plot the collaboration network
import matplotlib.pyplot as plt
plt.figure(figsize=(27, 20))
nx.draw(G, with_labels=True, node_size=3000, node_color="lightblue", font_size=16, font_weight="normal", edge_color="gray")
plt.title("Artist Collaboration Network")

#save figure:
plt.savefig("Artist Collaboration Network.pdf", format = "pdf")

plt.show()

# You can analyze further with centrality measures:
degree_centrality = nx.degree_centrality(G)
print(degree_centrality)  # Artists with most collaborations
# Out:
# ['nik p.', 'feuerherz', 'semino rossi', 'andreas gabalier', 'pur', 'stereoact', 'anna-maria zimmermann', 'matthias reim', 'ibo', 'andreas martin', 'andrea berg, semino rossi', 'wolfgang petry', 'die flippers', 'mickie krause, ko&ko', 'die paldauer', 'fantasy', 'helene fischer', 'ute freudenberg', 'sonia liebing', 'beatrice egli', 'allessa', 'roland kaiser, andrea berg', 'roland kaiser, maite kelly', 'nockis', 'nockis, melissa naschenweng', 'kerstin ott, giraffenaffen', 'dj ötzi, nik p.', 'stereoact, kerstin ott', 'maite kelly', 'stereoact, chris cronauer', 'christin stark', 'christin stark, matthias reim', 'kerstin ott, helene fischer', 'kerstin ott', 'die draufgänger', 'thomas anders, florian silbereisen', 'voxxclub', 'dj herzbeat, sarah engels', 'kerstin ott, howard carpendale', 'dj ötzi', 'michelle', 'roland kaiser, melissa naschenweng', 'helene fischer, luis fonsi', 'melissa naschenweng', 'roland kaiser', 'ben zucker, dj ötzi', 'andrea berg, kerstin ott', 'stereoact, al bano', 'stereoact, jürgen drews', 'mia julia', 'howard carpendale', 'die draufgänger, ikke hüftgold, dj robin', 'ben zucker', 'andrea berg']
# [('nik p.', 'feuerherz'), ('nik p.', 'dj ötzi, nik p.'), ('nik p.', 'nik p.'), ('feuerherz', 'feuerherz'), ('semino rossi', 'semino rossi'), ('andreas gabalier', 'andreas gabalier'), ('andreas gabalier', 'roland kaiser, melissa naschenweng'), ('pur', 'pur'), ('pur', 'stereoact'), ('anna-maria zimmermann', 'anna-maria zimmermann'), ('matthias reim', 'matthias reim'), ('ibo', 'ibo'), ('andreas martin', 'andrea berg, semino rossi'), ('wolfgang petry', 'wolfgang petry'), ('die flippers', 'die flippers'), ('mickie krause, ko&ko', 'mickie krause, ko&ko'), ('die paldauer', 'fantasy'), ('die paldauer', 'helene fischer'), ('fantasy', 'helene fischer'), ('helene fischer', 'helene fischer'), ('helene fischer', 'kerstin ott, giraffenaffen'), ('helene fischer', 'maite kelly'), ('ute freudenberg', 'sonia liebing'), ('beatrice egli', 'allessa'), ('roland kaiser, andrea berg', 'roland kaiser, andrea berg'), ('roland kaiser, maite kelly', 'roland kaiser, maite kelly'), ('nockis', 'nockis, melissa naschenweng'), ('dj ötzi, nik p.', 'dj ötzi, nik p.'), ('stereoact, kerstin ott', 'stereoact, kerstin ott'), ('maite kelly', 'maite kelly'), ('stereoact, chris cronauer', 'stereoact, chris cronauer'), ('christin stark', 'christin stark, matthias reim'), ('kerstin ott, helene fischer', 'kerstin ott'), ('kerstin ott, helene fischer', 'kerstin ott, helene fischer'), ('kerstin ott', 'kerstin ott'), ('die draufgänger', 'die draufgänger'), ('thomas anders, florian silbereisen', 'thomas anders, florian silbereisen'), ('voxxclub', 'voxxclub'), ('dj herzbeat, sarah engels', 'dj herzbeat, sarah engels'), ('kerstin ott, howard carpendale', 'kerstin ott, howard carpendale'), ('dj ötzi', 'dj ötzi'), ('michelle', 'michelle'), ('helene fischer, luis fonsi', 'helene fischer, luis fonsi'), ('melissa naschenweng', 'melissa naschenweng'), ('roland kaiser', 'roland kaiser'), ('ben zucker, dj ötzi', 'ben zucker, dj ötzi'), ('andrea berg, kerstin ott', 'andrea berg, kerstin ott'), ('stereoact, al bano', 'stereoact, al bano'), ('stereoact, jürgen drews', 'stereoact, jürgen drews'), ('mia julia', 'mia julia'), ('howard carpendale', 'howard carpendale'), ('die draufgänger, ikke hüftgold, dj robin', 'die draufgänger, ikke hüftgold, dj robin'), ('ben zucker', 'ben zucker'), ('andrea berg', 'andrea berg')]
# {'nik p.': 0.07547169811320754, 'feuerherz': 0.05660377358490566, 'semino rossi': 0.03773584905660377, 'andreas gabalier': 0.05660377358490566, 'pur': 0.05660377358490566, 'stereoact': 0.018867924528301886, 'anna-maria zimmermann': 0.03773584905660377, 'matthias reim': 0.03773584905660377, 'ibo': 0.03773584905660377, 'andreas martin': 0.018867924528301886, 'andrea berg, semino rossi': 0.018867924528301886, 'wolfgang petry': 0.03773584905660377, 'die flippers': 0.03773584905660377, 'mickie krause, ko&ko': 0.03773584905660377, 'die paldauer': 0.03773584905660377, 'fantasy': 0.03773584905660377, 'helene fischer': 0.11320754716981132, 'ute freudenberg': 0.018867924528301886, 'sonia liebing': 0.018867924528301886, 'beatrice egli': 0.018867924528301886, 'allessa': 0.018867924528301886, 'roland kaiser, andrea berg': 0.03773584905660377, 'roland kaiser, maite kelly': 0.03773584905660377, 'nockis': 0.018867924528301886, 'nockis, melissa naschenweng': 0.018867924528301886, 'kerstin ott, giraffenaffen': 0.018867924528301886, 'dj ötzi, nik p.': 0.05660377358490566, 'stereoact, kerstin ott': 0.03773584905660377, 'maite kelly': 0.05660377358490566, 'stereoact, chris cronauer': 0.03773584905660377, 'christin stark': 0.018867924528301886, 'christin stark, matthias reim': 0.018867924528301886, 'kerstin ott, helene fischer': 0.05660377358490566, 'kerstin ott': 0.05660377358490566, 'die draufgänger': 0.03773584905660377, 'thomas anders, florian silbereisen': 0.03773584905660377, 'voxxclub': 0.03773584905660377, 'dj herzbeat, sarah engels': 0.03773584905660377, 'kerstin ott, howard carpendale': 0.03773584905660377, 'dj ötzi': 0.03773584905660377, 'michelle': 0.03773584905660377, 'roland kaiser, melissa naschenweng': 0.018867924528301886, 'helene fischer, luis fonsi': 0.03773584905660377, 'melissa naschenweng': 0.03773584905660377, 'roland kaiser': 0.03773584905660377, 'ben zucker, dj ötzi': 0.03773584905660377, 'andrea berg, kerstin ott': 0.03773584905660377, 'stereoact, al bano': 0.03773584905660377, 'stereoact, jürgen drews': 0.03773584905660377, 'mia julia': 0.03773584905660377, 'howard carpendale': 0.03773584905660377, 'die draufgänger, ikke hüftgold, dj robin': 0.03773584905660377, 'ben zucker': 0.03773584905660377, 'andrea berg': 0.03773584905660377}

# %% [markdown]
# ### the most “connected” artists

# %%
#the most “connected” artists
degree_centrality = nx.degree_centrality(G)
most_central_artists = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)[:10]
print(most_central_artists)
# Out:
# [('helene fischer', 0.11320754716981132), ('nik p.', 0.07547169811320754), ('feuerherz', 0.05660377358490566), ('andreas gabalier', 0.05660377358490566), ('pur', 0.05660377358490566), ('dj ötzi, nik p.', 0.05660377358490566), ('maite kelly', 0.05660377358490566), ('kerstin ott, helene fischer', 0.05660377358490566), ('kerstin ott', 0.05660377358490566), ('semino rossi', 0.03773584905660377)]

# %% [markdown]
# ### how many of an artist’s collaborators are also collaborators with each other:

# %%
#how many of an artist’s collaborators are also collaborators with each other:
clustering = nx.clustering(G)
print(clustering)
# Out:
# {'nik p.': 0, 'feuerherz': 0, 'semino rossi': 0, 'andreas gabalier': 0, 'pur': 0, 'stereoact': 0, 'anna-maria zimmermann': 0, 'matthias reim': 0, 'ibo': 0, 'andreas martin': 0, 'andrea berg, semino rossi': 0, 'wolfgang petry': 0, 'die flippers': 0, 'mickie krause, ko&ko': 0, 'die paldauer': 1.0, 'fantasy': 1.0, 'helene fischer': 0.16666666666666666, 'ute freudenberg': 0, 'sonia liebing': 0, 'beatrice egli': 0, 'allessa': 0, 'roland kaiser, andrea berg': 0, 'roland kaiser, maite kelly': 0, 'nockis': 0, 'nockis, melissa naschenweng': 0, 'kerstin ott, giraffenaffen': 0, 'dj ötzi, nik p.': 0, 'stereoact, kerstin ott': 0, 'maite kelly': 0, 'stereoact, chris cronauer': 0, 'christin stark': 0, 'christin stark, matthias reim': 0, 'kerstin ott, helene fischer': 0, 'kerstin ott': 0, 'die draufgänger': 0, 'thomas anders, florian silbereisen': 0, 'voxxclub': 0, 'dj herzbeat, sarah engels': 0, 'kerstin ott, howard carpendale': 0, 'dj ötzi': 0, 'michelle': 0, 'roland kaiser, melissa naschenweng': 0, 'helene fischer, luis fonsi': 0, 'melissa naschenweng': 0, 'roland kaiser': 0, 'ben zucker, dj ötzi': 0, 'andrea berg, kerstin ott': 0, 'stereoact, al bano': 0, 'stereoact, jürgen drews': 0, 'mia julia': 0, 'howard carpendale': 0, 'die draufgänger, ikke hüftgold, dj robin': 0, 'ben zucker': 0, 'andrea berg': 0}

# %% [markdown]
# ### Collaborations by year

# %%
# Create a DataFrame with collaborations by year
collaborations_by_year = spotify_data_schlager_over_time.groupby(['release_year', 'name'])['artist'].apply(lambda x: list(x)).reset_index()

# Count collaborations per year
collaborations_by_year_count = collaborations_by_year.groupby('release_year')['name'].count()

# Plot collaborations by year
plt.figure(figsize=(12, 6))
collaborations_by_year_count.plot(kind='bar', color = "gold", edgecolor = "grey")
plt.title("Collaborations per Year")
plt.xlabel("Year")
plt.ylabel("Number of Collaborations")

#save figure:
plt.savefig("Number of Collarborations.pdf")

plt.show()

# %%
#see if collaborations are more popular than single tracks:

#count the artists:
artist_counts = spotify_data_schlager_over_time.groupby("name")["artist"].nunique()
print(artist_counts)
print("\n")

#add those artists with more than one artist at a track to the new multiple_artists column:
spotify_data_schlager_over_time["multiple_artists"] = spotify_data_schlager_over_time["name"].map(
    lambda x: "multiple_artists" if artist_counts[x] > 1 else "single_artist")

print(spotify_data_schlager_over_time.head())
# Out:
# name
# (Wer verdammt ist) Alice - 2009               1
# 1, 2, 3, 4: Heute Nacht da feiern wir!        1
# 100.000 leuchtende Sterne - Clubmix           1
# 100.000 leuchtende Sterne - Single Version    1
# 1000 Mal an dich gedacht - Remix 2013         1
#                                              ..
# Zieh dich an und geh                          1
# Ziwui Ziwui                                   1
# Zruck zu dir                                  1
# Zuckerpuppen                                  1
# Zärtlicher Tyrann - Remastered                1
# Name: artist, Length: 777, dtype: int64
#
#
#                                       name         artist  popularity  \
# 0          Sweet Caroline - Single Version        dj ötzi          55
# 1                     Ein Bett Im Kornfeld   jürgen drews          49
# 2       1000 und 1 Nacht - Remastered 2008     klaus lage          52
# 3  Eine neue Liebe ist wie ein neues Leben  jürgen marcus          48
# 4          Irgendwann, Irgendwo, Irgendwie   jürgen drews          45
#
#   release_date  release_year  mean_popularity_per_year multiple_artists  \
# 0   2008-01-01          2008                     33.64    single_artist
# 1   2008-10-17          2008                     33.64    single_artist
# 2   2008-01-01          2008                     33.64    single_artist
# 3   2008-10-11          2008                     33.64    single_artist
# 4   2008-10-17          2008                     33.64    single_artist
#
#   (41, multiple_artists) (54, multiple_artists) (143, multiple_artists)  ...  \
# 0       multiple_artists       multiple_artists        multiple_artists  ...
# 1       multiple_artists       multiple_artists        multiple_artists  ...
# 2       multiple_artists       multiple_artists        multiple_artists  ...
# 3       multiple_artists       multiple_artists        multiple_artists  ...
# 4       multiple_artists       multiple_artists        multiple_artists  ...
#
#   (507, multiple_artists) (521, multiple_artists) (537, multiple_artists)  \
# 0        multiple_artists        multiple_artists        multiple_artists
# 1        multiple_artists        multiple_artists        multiple_artists
# 2        multiple_artists        multiple_artists        multiple_artists
# 3        multiple_artists        multiple_artists        multiple_artists
# 4        multiple_artists        multiple_artists        multiple_artists
#
#   (553, multiple_artists) (635, multiple_artists) (681, multiple_artists)  \
# 0        multiple_artists        multiple_artists        multiple_artists
# 1        multiple_artists        multiple_artists        multiple_artists
# 2        multiple_artists        multiple_artists        multiple_artists
# 3        multiple_artists        multiple_artists        multiple_artists
# 4        multiple_artists        multiple_artists        multiple_artists
#
#   (682, multiple_artists) (711, multiple_artists) (739, multiple_artists)  \
# 0        multiple_artists        multiple_artists        multiple_artists
# 1        multiple_artists        multiple_artists        multiple_artists
# 2        multiple_artists        multiple_artists        multiple_artists
# 3        multiple_artists        multiple_artists        multiple_artists
# 4        multiple_artists        multiple_artists        multiple_artists
#
#   (795, multiple_artists)
# 0        multiple_artists
# 1        multiple_artists
# 2        multiple_artists
# 3        multiple_artists
# 4        multiple_artists
#
# [5 rows x 38 columns]

# %%
#Visualize the comparison between single vs multiple artists

popularity_comparison = spotify_data_schlager_over_time.groupby('multiple_artists')['popularity'].mean()

popularity_comparison.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title("Average Popularity of Tracks with Single vs Multiple Artists")
plt.ylabel("Average Popularity")
plt.xlabel("Artist Type (Single/Multiple)")
plt.xticks(rotation=0)

#safe bevore show figure:
plt.savefig("Average Popularity of Tracks with Single vs Multiple Artists.pdf")

plt.show()
